# %% [markdown]
# Named Entity means anything that is a real-world object such as a person, a place, any organisation, any product which has a name. For example – “My name is Aman, and I and a Machine Learning Trainer”. In this sentence the name “Aman”, the field or subject “Machine Learning” and the profession “Trainer” are named entities.

# %%
import pandas as pd
import numpy as np

data=pd.read_csv(r'C:\Users\amany\Desktop\archive datasets\ner_dataset.csv',encoding= 'unicode_escape')
print(data.shape)
data.head()
# Out:
# (1048575, 4)
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %%
data.isnull().sum()
# Out:
# Sentence #    1000616
# Word                0
# POS                 0
# Tag                 0
# dtype: int64

# %% [markdown]
# ## Data Preparation for NN

# %% [markdown]
# I will train a Neural Network for the task of Named Entity Recognition (NER). So we need to do some modifications in the data to prepare it in such a manner so that it can easily fit into a neutral network. I will start this step by extracting the mappings that are required to train the neural network:

# %%
from itertools import chain
def get_dict_map(data,token_or_tags):
    tok2idx={}
    idx2tok={}
    
    if token_or_tags=='token':
        vocab=list(set(data['Word'].to_list()))
        print("Vocab : \n",vocab)
    else:
        vocab=list(set(data['Tag'].to_list()))
        print("Vocab : \n",vocab)
        
    idx2tok={idx:tok for idx,tok in enumerate(vocab)}
    tok2idx={tok:idx for idx,tok in enumerate(vocab)}
    
    return tok2idx,idx2tok

# %%
token2idx,idx2tok=get_dict_map(data,'token')
# Out:
# Vocab :
#  ['turned', 'induced', 'commits', 'Din', 'winterized', 'Kabal', 'Aurangabad', 'returned', 'regain', 'cruel', 'able', 'spray', 'Nastase', 'warn', 'Kira', 'Alois', 'canister', 'Nesnera', 'trunks', 'Wallachia', 'CIA-military', 'Embassy', 'U.N.-brokered', 'Unique', 'Elsa', 'climbing', 'core', 'Actually', 'bidding', 'conscripted', 'reveals', 'sure', 'Mwaluka', '1682', 'Possible', 'pre-Katrina', 'Norwegian', 'tents', 'pro-Hezbollah', 'Paerson', '30', 'Kfar', 'peacekeepers', 'warrior', 'prototype', 'Antonio', 'load', 'Notes', '13,406', 'inequities', 'Adkins', 'Blades', 'Roosevelt', 'Caracas-based', 'raided', 'Shares', 'embryos', 'reduces', '232', 'NIGHTINGALE', 'Commando', 'drug-trafficking', 'concluding', '71', 'rotate', 'Wave', 'Sino-Tibetan', 'Natanz', 'posted', 'Wal-Marts', 'Henin', 'circa', 'outposts', 'to', 'sponsorship', 'Hat', 'camps', 'inevitably', 'Nicaraguan', 'MERCURY', 'grief', 'cardinals', 'H-2A', 'Kyoto-style', 'implementation', 'Children', 'staff-reduction', 'prevented', 'cat', 'Shevchenko', 'Tayseer', 'poor', 'metropolitan', 'Nabarro', 'Stanilas', 'Shawal', 'Karen', '22-month', 'dismisses', 'anti-graft', 'renting', 'per-capita', 'suburb', 'contempt', 'pest', 'trampled', 'come', 'Locals', 'Pandas', 'angry', 'donate', 'three-hour', 'prevail', 'al-Otari', 'Patan', 'verified', 'outrageous', 'levitates', 'Manouchehr', 'Road', 'Equator', 'Museum', 'Dheere', 'resales', 'unsanitary', 'vine', 'Gajdosova', 'wedding', 'quadrupled', 'rift', 'wept', 'Dong', 'land-grab', 'Yugoslav', '1932', '40-car', 'Instead', 'Brillantes', 'Higher', 'Sepehri', 'Craybas', 'Dimitris', 'merchant', 'airstrike', 'reverence', 'Lambeth', 'Samuels', 'Hemisphere', 'Under-20', 'Bangguo', 'shares', 'Robredo', 'Bedford', 'appeal', 'surrounded', 'importer', 'Cubanization', 'Sawyer', 'Muskie', 'thanks', 'happens', 'Marti', 'digital', 'mistreating', 'Dravid', 'Reinhardt', 'domination', '11-judge', 'detachment', 'di', 'Heinonen', 'Nkurunziza', 'launchers', 'accusing', 'Black', 'Statoil', 'Johnston', 'Hasegawa', 'Anderson', 'Mozambican', 'rank-and-file', 'brisk', 'wake', 'finalized', 'Communities', '26,500', 'recently-detained', 'pouring', 'investigates', 'Hajj', 'intense', '2006', 'Everado', 'earth-penetrating', 'fourth-highest', 'remote', 'phased', 'Shinui', '10,000-square-kilometer', 'Shlomo', 'earthquakes', 'Amelie', 'Restrepo', 'lithium', 'day-time', 'improved', 'de-miners', 'Sar-dan', 'torchbearers', 'kitchen', 'Haji', 'basket', 'Maher', 'ethnicity', 'corals', 'House', 'suggesting', 'Farraj', 'one-million', 'Harrison', 'Hellenic', 'prohibit', 'Asagoe', 'shifted', 'upgraded', 'Mohammad', 'harm', 'Telephone', '5,52,300', 'forcibly', "L'OUVERTURE", 'Genro', 'Hezbollah-operated', 'Carolina', 'newly-formed', 'Ousamane', 'whiskey', 'Maritime', 'close', 'McNeill', 'buttressed', 'Mirko', 'AP', 'dunking', 'grounded', 'S&P', 'seventh-seeded', 'best-known', 'Characterized', 'Songhua', 'Patricia', 'anchored', 'repose', '41-year-old', 'Delegation', 'blacks', 'Haley', 'Said-uz', 'premier', 'Constitutional', 'boxes', '168', 'provincial', 'Khanna', 'Geneva-based', 'Khar', 'Hunter', 'Mekorot', 'Culture', 'canning', 'helpless', 'Nkrumah', 'abdication', 'mark', 'cropped', 'Yvelines', 'Automated', 'Passover', 'Laghman', 'granite', 'loophole', 'kinds', 'cordoned', 'Parliament', '214', 'barring', 'Kirchner', 'piling', 'Baluch', 'conflict', 'bodyguards', 'Polytechnic', 'priests', 'Fisher', 'Iraqi', 'Tension', 'converging', 'Senate', 'Thomas', 'marched', 'firebombing', 'Lashkar-e-Islam', 'chute', 'inhumanely', 'marrying', 'guilt', 'Skelleftea', 'Moallem', 'widely-used', 'comprising', 'slideshow', 'Animals', 'evolves', 'apologise', 'anybody', 'Exploitation', 'Hyung-taik', 'treasurer', '454', 'Vocalist', 'Unpredictable', 'weak', 'queen', '1850', 'Earth-like', 'Scud', 'strongest-ever', '0.161', 'Mother', 'straight-set', 'Moqtada', 'Bekasi', 'property', 'al-Sunnah', 'frequenting', 'kerosene', 'Kihonge', 'agencies', 'Tensions', 'Patty', 'estranged', 'teach', 'ANC-led', 'examinations', ...

# %%
tag2idx,idx2tag=get_dict_map(data,'tag')
# Out:
# Vocab :
#  ['I-geo', 'I-nat', 'B-art', 'I-org', 'B-geo', 'I-per', 'I-gpe', 'B-tim', 'B-per', 'B-gpe', 'I-eve', 'B-org', 'O', 'I-art', 'B-nat', 'I-tim', 'B-eve']

# %% [markdown]
# #### Now I will transform the columns in the data to extract the sequential data for our neural network:

# %%
data['Word_idx']=data['Word'].map(token2idx)
data['Tag_idx']=data['Tag'].map(tag2idx)
data_fillna=data.fillna(method='ffill',axis=0)

##Groupby and collects column

data_group=data_fillna.groupby(['Sentence #'],as_index=False)['Word','POS','Tag','Word_idx','Tag_idx'].agg(lambda x:list(x))
# Out:
# F:\anaconda\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   import sys

# %%
print(data.shape)
data.head()
# Out:
# (1048575, 6)
#     Sentence #           Word  POS Tag  Word_idx  Tag_idx
# 0  Sentence: 1      Thousands  NNS   O      7350       12
# 1          NaN             of   IN   O      4480       12
# 2          NaN  demonstrators  NNS   O     17537       12
# 3          NaN           have  VBP   O     34021       12
# 4          NaN        marched  VBN   O       299       12

# %%
data_fillna.head()
# Out:
#     Sentence #           Word  POS Tag  Word_idx  Tag_idx
# 0  Sentence: 1      Thousands  NNS   O      7350       12
# 1  Sentence: 1             of   IN   O      4480       12
# 2  Sentence: 1  demonstrators  NNS   O     17537       12
# 3  Sentence: 1           have  VBP   O     34021       12
# 4  Sentence: 1        marched  VBN   O       299       12

# %%
data_group
# Out:
#             Sentence #                                               Word  \
# 0          Sentence: 1  [Thousands, of, demonstrators, have, marched, ...
# 1         Sentence: 10  [Iranian, officials, say, they, expect, to, ge...
# 2        Sentence: 100  [Helicopter, gunships, Saturday, pounded, mili...
# 3       Sentence: 1000  [They, left, after, a, tense, hour-long, stand...
# 4      Sentence: 10000  [U.N., relief, coordinator, Jan, Egeland, said...
# ...                ...                                                ...
# 47954   Sentence: 9995  [Opposition, leader, Mir, Hossein, Mousavi, ha...
# 47955   Sentence: 9996  [On, Thursday, ,, Iranian, state, media, publi...
# 47956   Sentence: 9997  [Following, Iran, 's, disputed, June, 12, elec...
# 47957   Sentence: 9998  [Since, then, ,, authorities, have, held, publ...
# 47958   Sentence: 9999  [The, United, Nations, is, praising, the, use,...
#
#                                                      POS  \
# 0      [NNS, IN, NNS, VBP, VBN, IN, NNP, TO, VB, DT, ...
# 1      [JJ, NNS, VBP, PRP, VBP, TO, VB, NN, TO, JJ, J...
# 2      [NN, NNS, NNP, VBD, JJ, NNS, IN, DT, NNP, JJ, ...
# 3         [PRP, VBD, IN, DT, NN, JJ, NN, IN, NN, NNS, .]
# 4      [NNP, NN, NN, NNP, NNP, VBD, NNP, ,, NNP, ,, J...
# ...                                                  ...
# 47954  [NNP, NN, NNP, NNP, NNP, VBZ, VBN, PRP, VBZ, T...
# 47955  [IN, NNP, ,, JJ, NN, NNS, VBN, DT, NN, IN, DT,...
# 47956  [VBG, NNP, POS, JJ, NNP, CD, NNS, ,, NNS, NNS,...
# 47957  [IN, RB, ,, NNS, VBP, VBN, JJ, NNS, IN, DT, VB...
# 47958  [DT, NNP, NNP, VBZ, VBG, DT, NN, IN, JJ, NNS, ...
#
#                                                      Tag  \
# 0      [O, O, O, O, O, O, B-geo, O, O, O, O, O, B-geo...
# 1      [B-gpe, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2      [O, O, B-tim, O, O, O, O, O, B-geo, O, O, O, O...
# 3                      [O, O, O, O, O, O, O, O, O, O, O]
# 4      [B-geo, O, O, B-per, I-per, O, B-tim, O, B-geo...
# ...                                                  ...
# 47954  [O, O, O, B-per, I-per, O, O, O, O, O, O, O, O...
# 47955  [O, B-tim, O, B-gpe, O, O, O, O, O, O, O, O, B...
# 47956  [O, B-geo, O, O, B-tim, I-tim, O, O, O, O, O, ...
# 47957  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 47958  [O, B-org, I-org, O, O, O, O, O, O, O, O, O, O...
#
#                                                 Word_idx  \
# 0      [7350, 4480, 17537, 34021, 299, 5469, 1513, 73...
# 1      [24260, 19149, 14239, 4764, 34324, 73, 535, 18...
# 2      [13915, 25477, 3424, 34806, 1746, 13942, 19535...
# 3      [32362, 25674, 34431, 17361, 6024, 30618, 1596...
# 4      [2792, 3684, 16087, 18601, 26253, 4835, 30844,...
# ...                                                  ...
# 47954  [5959, 3806, 15988, 18083, 27883, 23195, 4835,...
# 47955  [11017, 14165, 27746, 24260, 9865, 17205, 2073...
# 47956  [2988, 2341, 4408, 31741, 13443, 32276, 3318, ...
# 47957  [8219, 14540, 27746, 21629, 34021, 5171, 6998,...
# 47958  [8333, 22922, 22898, 11388, 8255, 28383, 9999,...
#
#                                                  Tag_idx
# 0      [12, 12, 12, 12, 12, 12, 4, 12, 12, 12, 12, 12...
# 1      [9, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12...
# 2      [12, 12, 7, 12, 12, 12, 12, 12, 4, 12, 12, 12,...
# 3           [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# 4      [4, 12, 12, 8, 5, 12, 7, 12, 4, 12, 9, 12, 9, ...
# ...                                                  ...
# 47954  [12, 12, 12, 8, 5, 12, 12, 12, 12, 12, 12, 12,...
# 47955  [12, 7, 12, 9, 12, 12, 12, 12, 12, 12, 12, 12,...
# 47956  [12, 4, 12, 12, 7, 15, 12, 12, 12, 12, 12, 12,...
# 47957  [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 1...
# 47958  [12, 11, 3, 12, 12, 12, 12, 12, 12, 12, 12, 12...
#
# [47959 rows x 6 columns]

# %% [markdown]
# Now I will split the data into training and test sets. I will create a function for splitting the data because the LSTM layers accept sequences of the same length only. So every sentence that appears as integer in the data must be padded with the same length:

# %%
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

def get_pad_train_test_val(data_group, data):
    
    ##get max token and tags
    n_tokens=len(list(set(data['Word'].to_list())))
    n_tags=len(list(set(data['Tag'].to_list())))
    print("No. of tokens and tags : ",n_tokens,n_tags)
    
    ##pad tokens (X var)
    tokens=data_group['Word_idx'].tolist()
    maxlen=max([len(s) for s in tokens])
    pad_tokens=pad_sequences(tokens,maxlen=maxlen,dtype='int32',padding='post',value=n_tokens-1)
    
    ##pad tag (y var)
    tags=data_group['Tag_idx'].tolist()
    pad_tags=pad_sequences(tags,maxlen=maxlen,dtype='int32',padding='post',value=tag2idx["O"])
    n_tags=len(tag2idx)
    pad_tags=[to_categorical(i,num_classes=n_tags) for i in pad_tags]
    
    ##split train, test and validation set
    tokens_,test_tokens,tags_,test_tags=train_test_split(pad_tokens,pad_tags,test_size=0.1,train_size=0.9,random_state=2020)
    train_tokens,val_tokens,train_tags,val_tags=train_test_split(tokens_,tags_,test_size=0.25,train_size=0.75,random_state=2020)
    
    return train_tokens,val_tokens,test_tokens,train_tags,val_tags,test_tags

train_tokens, val_tokens, test_tokens, train_tags, val_tags, test_tags = get_pad_train_test_val(data_group, data)
# Out:
# No. of tokens and tags :  35178 17

# %% [markdown]
# ### Training Neural Network for Named Entity Recognition (NER)
# Now, I will proceed with training the neural network architecture of our model. So let’s start with importing all the packages we need for training our neural network:

# %%
import numpy as np
import tensorflow
from tensorflow.keras import Sequential, Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from tensorflow.keras.utils import plot_model
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)

# %% [markdown]
# The layer below will take the dimensions from the LSTM layer and will give the maximum length and maximum tags as an output:

# %%
input_dim = len(list(set(data['Word'].to_list())))+1
output_dim = 64
input_length = max([len(s) for s in data_group['Word_idx'].tolist()])
n_tags = len(tag2idx)

# %%
input_dim,input_length,n_tags
# Out:
# (35179, 104, 17)

# %%
def get_bilstm_lstm_model():
    model = Sequential()

    # Add Embedding layer
    model.add(Embedding(input_dim=input_dim, output_dim=output_dim, input_length=input_length))

    # Add bidirectional LSTM
    model.add(Bidirectional(LSTM(units=output_dim, return_sequences=True, dropout=0.2, recurrent_dropout=0.2), merge_mode = 'concat'))

    # Add LSTM
    model.add(LSTM(units=output_dim, return_sequences=True, dropout=0.5, recurrent_dropout=0.5))

    # Add timeDistributed Layer
    model.add(TimeDistributed(Dense(n_tags, activation="relu")))

    #Optimiser 
    # adam = k.optimizers.Adam(lr=0.0005, beta_1=0.9, beta_2=0.999)

    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()
    
    return model

# %%
def train_model(X, y, model):
    loss = list()
    for i in range(5):
        # fit model for one epoch on this sequence
        hist = model.fit(X, y, batch_size=1000, verbose=1, epochs=1, validation_split=0.2)
        loss.append(hist.history['loss'][0])
    return loss

# %%
results = pd.DataFrame()
model_bilstm_lstm = get_bilstm_lstm_model()
plot_model(model_bilstm_lstm)
results['with_add_lstm'] = train_model(train_tokens, np.array(train_tags), model_bilstm_lstm)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 104, 64)           2251456
# _________________________________________________________________
# bidirectional (Bidirectional (None, 104, 128)          66048
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 104, 64)           49408
# _________________________________________________________________
# time_distributed (TimeDistri (None, 104, 17)           1105
# =================================================================
# Total params: 2,368,017
# Trainable params: 2,368,017
# Non-trainable params: 0
# _________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# 26/26 [==============================] - 207s 7s/step - loss: nan - accuracy: 0.1035 - val_loss: nan - val_accuracy: 0.0014
# 26/26 [==============================] - 233s 9s/step - loss: nan - accuracy: 0.0015 - val_loss: nan - val_accuracy: 0.0014
# 26/26 [==============================] - 140s 5s/step - loss: nan - accuracy: 0.0015 - val_loss: nan - val_accuracy: 0.0014
# 26/26 [==============================] - 141s 5s/step - loss: nan - accuracy: 0.0015 - val_loss: nan - val_accuracy: 0.0014
# 26/26 [==============================] - 149s 6s/step - loss: nan - accuracy: 0.0015 - val_loss: nan - val_accuracy: 0.0014

# %%
results
# Out:
#    with_add_lstm
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# !pip install -U spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.0.6-cp37-cp37m-win_amd64.whl (11.7 MB)
# Collecting thinc<8.1.0,>=8.0.3
#   Downloading thinc-8.0.3-cp37-cp37m-win_amd64.whl (1.0 MB)
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp37-cp37m-win_amd64.whl (6.5 MB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp37-cp37m-win_amd64.whl (35 kB)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in f:\anaconda\lib\site-packages (from spacy) (3.7.4.3)
# Collecting catalogue<2.1.0,>=2.0.3
#   Downloading catalogue-2.0.4-py3-none-any.whl (16 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.4
#   Downloading spacy_legacy-3.0.5-py2.py3-none-any.whl (12 kB)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy>=1.15.0 in f:\anaconda\lib\site-packages (from spacy) (1.18.0)
# Collecting packaging>=20.0
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in f:\anaconda\lib\site-packages (from spacy) (2.22.0)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp37-cp37m-win_amd64.whl (108 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.5.2-py3-none-any.whl (42 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp37-cp37m-win_amd64.whl (20 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in f:\anaconda\lib\site-packages (from spacy) (4.41.1)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.1-cp37-cp37m-win_amd64.whl (450 kB)
# Requirement already satisfied: setuptools in f:\anaconda\lib\site-packages (from spacy) (41.4.0)
# Requirement already satisfied: jinja2 in f:\anaconda\lib\site-packages (from spacy) (2.11.3)
# Collecting pydantic<1.8.0,>=1.7.1
#   Downloading pydantic-1.7.3-cp37-cp37m-win_amd64.whl (1.7 MB)
# Requirement already satisfied: zipp>=0.5 in f:\anaconda\lib\site-packages (from catalogue<2.1.0,>=2.0.3->spacy) (0.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in f:\anaconda\lib\site-packages (from packaging>=20.0->spacy) (2.4.2)
# Collecting smart-open<4.0.0,>=2.2.0
#   Downloading smart_open-3.0.0.tar.gz (113 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in f:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in f:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in f:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in f:\anaconda\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: more-itertools in f:\anaconda\lib\site-packages (from zipp>=0.5->catalogue<2.1.0,>=2.0.3->spacy) (7.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in f:\anaconda\lib\site-packages (from jinja2->spacy) (1.1.1)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-3.0.0-py3-none-any.whl size=107097 sha256=838b1877dd8ecbad737c54aa9cfbf95b79af5312b79165832ded8747aea839f7
#   Stored in directory: c:\users\amany\appdata\local\pip\cache\wheels\83\a6\12\bf3c1a667bde4251be5b7a3368b2d604c9af2105b5c1cb1870
# Successfully built smart-open
# Installing collected packages: murmurhash, cymem, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, blis, thinc, spacy-legacy, pathy, packaging, spacy
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.3
#     Uninstalling pydantic-1.3:
#       Successfully uninstalled pydantic-1.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 19.2
#     Uninstalling packaging-19.2:
#       Successfully uninstalled packaging-19.2
# Successfully installed blis-0.7.4 catalogue-2.0.4 cymem-2.0.5 murmurhash-1.0.5 packaging-20.9 pathy-0.5.2 preshed-3.0.5 pydantic-1.7.3 smart-open-3.0.0 spacy-3.0.6 spacy-legacy-3.0.5 srsly-2.4.1 thinc-8.0.3 typer-0.3.2 wasabi-0.8.2
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in f:\anaconda\lib\site-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.22.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.1)
# Requirement already satisfied: pathy>=0.3.5 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.5.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: packaging>=20.0 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.9)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: jinja2 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.3)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.3)
# Requirement already satisfied: numpy>=1.15.0 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.18.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.7.4.3)
# Requirement already satisfied: setuptools in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (41.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.41.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in f:\anaconda\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: zipp>=0.5 in f:\anaconda\lib\site-packages (from catalogue<2.1.0,>=2.0.3->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in f:\anaconda\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in f:\anaconda\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in f:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in f:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in f:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.24.2)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in f:\anaconda\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: more-itertools in f:\anaconda\lib\site-packages (from zipp>=0.5->catalogue<2.1.0,>=2.0.3->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in f:\anaconda\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.0.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2021-05-07 17:00:56.854591: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-05-07 17:00:56.854695: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (f:\anaconda\lib\site-packages)

# %%
# pip install -U spacy
# python -m spacy download en_core_web_sm

import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')
text = nlp('Hi, My name is Aman\n I am from India \n I want to work with Google \n Steve Jobs is My Inspiration')
displacy.render(text, style = 'ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Hi, My name is
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aman
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# I am from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# I want to work with Google </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Jobs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is My Inspiration</div></span>
